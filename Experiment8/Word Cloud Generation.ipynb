# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import cv2

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('popular', quiet=True)
# Out:
# [nltk_data] Downloading package punkt to /Users/parthpsg/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/parthpsg/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
image = cv2.imread('/content/mask.png', cv2.IMREAD_GRAYSCALE)
# image = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)[1]
# Out:
# [ WARN:0@17.375] global loadsave.cpp:241 findDecoder imread_('/content/mask.png'): can't open/read file: check file path/integrity

# %%
stopwrds = set(stopwords.words('english'))

def word_cloud(text):
  # tokens = word_tokenize(text)
  wc = WordCloud(width=3000, height = 3000, stopwords = stopwrds, mask = image).generate(text)
  plt.imshow(wc)
  plt.axis('off')
  plt.show()

# %%
text = '''Parth Gala is a talented AI and data science enthusiast, currently pursuing a Bachelor of Technology at Dwarkadas J. Sanghvi College of Engineering. His technical expertise spans various cutting-edge technologies, including web development, machine learning, and AI model deployment. Parth’s recent projects, such as building a complete e-commerce app with NextJs and a movie recommendation system, highlight his ability to manage and implement real-time data handling, secure user authentication, and data-driven insights using sophisticated tech stacks like React.js, MongoDB, MySQL, and Python.

A standout initiative in Parth’s portfolio is a charity website he developed for the Jivam Group. Leading both front-end and back-end development, he successfully created secure master login functionalities and curated content to effectively communicate the organization’s mission. Parth’s versatility in project management and technology integration is also evident in his contributions to hackathons, such as his winning project at TechBlitz Hackathon where he utilized AI for web development.

Parth’s passion for AI extends beyond his own work, as he actively mentors in the InfoMatrix club, sharing his knowledge of full-stack development and AI-ML technologies. He is a rising expert in fields like data science, AI model deployment, and secure web development, poised to make significant contributions to the industry ￼.'''

word_cloud(text)
